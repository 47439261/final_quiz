# %% [markdown]
# ## 各csvの説明、kaggleの当コンペHPより

# %%
import pandas as pd 
df = pd.read_csv("HomeCredit_columns_description.csv")

# %% [markdown]
# ### application_{train|test}.csv
#
# This is the main table, broken into two files for Train (with TARGET) and Test (without TARGET).
# Static data for all applications. One row represents one loan in our data sample.
#
# メインの表。train.csvとtest.csvがある。全申請に関する統計情報が含まれている。各行は各々のローンに対応している

# %%
df[df["Table"]=="application_{train|test}.csv"].drop(["Table"],axis=1)
# Out:
#      Unnamed: 0  Unnamed: 0.1                         Row  \
# 0             0             1                  SK_ID_CURR
# 1             1             2                      TARGET
# 2             2             5          NAME_CONTRACT_TYPE
# 3             3             6                 CODE_GENDER
# 4             4             7                FLAG_OWN_CAR
# 5             5             8             FLAG_OWN_REALTY
# 6             6             9                CNT_CHILDREN
# 7             7            10            AMT_INCOME_TOTAL
# 8             8            11                  AMT_CREDIT
# 9             9            12                 AMT_ANNUITY
# 10           10            13             AMT_GOODS_PRICE
# 11           11            14             NAME_TYPE_SUITE
# 12           12            15            NAME_INCOME_TYPE
# 13           13            16         NAME_EDUCATION_TYPE
# 14           14            17          NAME_FAMILY_STATUS
# ...

# %% [markdown]
# ### bureau.csv
#
# All client's previous credits provided by other financial institutions that were reported to Credit Bureau (for clients who have a loan in our sample).
# For every loan in our sample, there are as many rows as number of credits the client had in Credit Bureau before the application date.
#
# 全クライアントの過去のクレジット情報（信用調査機関より提供）。全ローンについて、信用調査機関が所有していた、申請日付以前のクライアントのクレジット情報分だけ行が追加されている。

# %%
df[df["Table"]=="bureau.csv"].drop(["Table"],axis=1)
# Out:
#      Unnamed: 0                     Row  \
# 122         125              SK_ID_CURR
# 123         126            SK_BUREAU_ID
# 124         127           CREDIT_ACTIVE
# 125         128         CREDIT_CURRENCY
# 126         129             DAYS_CREDIT
# 127         130      CREDIT_DAY_OVERDUE
# 128         131     DAYS_CREDIT_ENDDATE
# 129         132       DAYS_ENDDATE_FACT
# 130         133  AMT_CREDIT_MAX_OVERDUE
# 131         134      CNT_CREDIT_PROLONG
# 132         135          AMT_CREDIT_SUM
# 133         136     AMT_CREDIT_SUM_DEBT
# 134         137    AMT_CREDIT_SUM_LIMIT
# 135         138  AMT_CREDIT_SUM_OVERDUE
# 136         139             CREDIT_TYPE
# 137         140      DAYS_CREDIT_UPDATE
# 138         141             AMT_ANNUITY
#
#                                            Description  \
# 122  ID of loan in our sample - one loan in our sam...
# 123  Recoded ID of previous Credit Bureau credit re...
# 124  Status of the Credit Bureau (CB) reported credits
# ...

# %% [markdown]
# ### bureau_balance.csv
#
# Monthly balances of previous credits in Credit Bureau.
# This table has one row for each month of history of every previous credit reported to Credit Bureau – i.e the table has (#loans in sample * # of relative previous credits * # of months where we have some history observable for the previous credits) rows.
#
# bureau.csvを月別にバランスしたもの？

# %%
df[df["Table"]=="bureau_balance.csv"].drop(["Table"],axis=1)
# Out:
#      Unnamed: 0             Row  \
# 139         142    SK_BUREAU_ID
# 140         143  MONTHS_BALANCE
# 141         144          STATUS
#
#                                            Description  \
# 139  Recoded ID of Credit Bureau credit (unique cod...
# 140  Month of balance relative to application date ...
# 141  Status of Credit Bureau loan during the month ...
#
#                                    Special
# 139                                 hashed
# 140  time only relative to the application
# 141                                    NaN

# %% [markdown]
# ### POS_CASH_balance.csv
#
# Monthly balance snapshots of previous POS (point of sales) and cash loans that the applicant had with Home Credit.
# This table has one row for each month of history of every previous credit in Home Credit (consumer credit and cash loans) related to loans in our sample – i.e. the table has (#loans in sample * # of relative previous credits * # of months in which we have some history observable for the previous credits) rows.
#
# よくわからん。

# %%
df[df["Table"]=="POS_CASH_balance.csv"].drop(["Table"],axis=1)
# Out:
#      Unnamed: 0                    Row  \
# 142         145            SK_ID_PREV
# 143         146             SK_ID_CURR
# 144         147         MONTHS_BALANCE
# 145         148         CNT_INSTALMENT
# 146         149  CNT_INSTALMENT_FUTURE
# 147         150   NAME_CONTRACT_STATUS
# 148         151                 SK_DPD
# 149         152             SK_DPD_DEF
#
#                                            Description  \
# 142  ID of previous credit in Home Credit related t...
# 143                           ID of loan in our sample
# 144  Month of balance relative to application date ...
# 145     Term of previous credit (can change over time)
# 146    Installments left to pay on the previous credit
# 147                   Contract status during the month
# 148  DPD (days past due) during the month of previo...
# 149  DPD during the month with tolerance (debts wit...
#
#                                    Special
# 142                                    NaN
# ...

# %% [markdown]
# ### credit_card_balance.csv
#
# Monthly balance snapshots of previous credit cards that the applicant has with Home Credit.
# This table has one row for each month of history of every previous credit in Home Credit (consumer credit and cash loans) related to loans in our sample – i.e. the table has (#loans in sample * # of relative previous credit cards * # of months where we have some history observable for the previous credit card) rows.
#
# よくわからん。

# %%
df[df["Table"]=="credit_card_balance.csv"].drop(["Table"],axis=1)
# Out:
#      Unnamed: 0                         Row  \
# 150         153                 SK_ID_PREV
# 151         154                  SK_ID_CURR
# 152         155              MONTHS_BALANCE
# 153         156                 AMT_BALANCE
# 154         157     AMT_CREDIT_LIMIT_ACTUAL
# 155         158    AMT_DRAWINGS_ATM_CURRENT
# 156         159        AMT_DRAWINGS_CURRENT
# 157         160  AMT_DRAWINGS_OTHER_CURRENT
# 158         161    AMT_DRAWINGS_POS_CURRENT
# 159         162     AMT_INST_MIN_REGULARITY
# 160         163         AMT_PAYMENT_CURRENT
# 161         164   AMT_PAYMENT_TOTAL_CURRENT
# 162         165    AMT_RECEIVABLE_PRINCIPAL
# 163         166               AMT_RECIVABLE
# 164         167        AMT_TOTAL_RECEIVABLE
# 165         168    CNT_DRAWINGS_ATM_CURRENT
# 166         169        CNT_DRAWINGS_CURRENT
# 167         170  CNT_DRAWINGS_OTHER_CURRENT
# 168         171    CNT_DRAWINGS_POS_CURRENT
# 169         172   CNT_INSTALMENT_MATURE_CUM
# ...

# %% [markdown]
# ### previous_application.csv
#
# All previous applications for Home Credit loans of clients who have loans in our sample.
# There is one row for each previous application related to loans in our data sample.

# %%
df[df["Table"]=="previous_application.csv"].drop(["Table"],axis=1)
# Out:
#      Unnamed: 0                          Row  \
# 173         176                  SK_ID_PREV
# 174         177                   SK_ID_CURR
# 175         178           NAME_CONTRACT_TYPE
# 176         179                  AMT_ANNUITY
# 177         180              AMT_APPLICATION
# 178         181                   AMT_CREDIT
# 179         182             AMT_DOWN_PAYMENT
# 180         183              AMT_GOODS_PRICE
# 181         184   WEEKDAY_APPR_PROCESS_START
# 182         185      HOUR_APPR_PROCESS_START
# 183         186  FLAG_LAST_APPL_PER_CONTRACT
# 184         187       NFLAG_LAST_APPL_IN_DAY
# 185         188             NFLAG_MICRO_CASH
# 186         189            RATE_DOWN_PAYMENT
# 187         190        RATE_INTEREST_PRIMARY
# 188         191     RATE_INTEREST_PRIVILEGED
# 189         192       NAME_CASH_LOAN_PURPOSE
# 190         193         NAME_CONTRACT_STATUS
# 191         194                DAYS_DECISION
# 192         195            NAME_PAYMENT_TYPE
# ...

# %% [markdown]
# ### installments_payments.csv
#
# Repayment history for the previously disbursed credits in Home Credit related to the loans in our sample.
# There is a) one row for every payment that was made plus b) one row each for missed payment.
# One row is equivalent to one payment of one installment OR one installment corresponding to one payment of one previous Home Credit credit related to loans in our sample.

# %%
df[df["Table"]=="installments_payments.csv"].drop(["Table"],axis=1)
# Out:
#      Unnamed: 0                     Row  \
# 211         214             SK_ID_PREV
# 212         215              SK_ID_CURR
# 213         216  NUM_INSTALMENT_VERSION
# 214         217   NUM_INSTALMENT_NUMBER
# 215         218         DAYS_INSTALMENT
# 216         219      DAYS_ENTRY_PAYMENT
# 217         220          AMT_INSTALMENT
# 218         221             AMT_PAYMENT
#
#                                            Description  \
# 211  ID of previous credit in Home credit related t...
# 212                           ID of loan in our sample
# 213  Version of installment calendar (0 is for cred...
# 214            On which installment we observe payment
# 215  When the installment of previous credit was su...
# 216  When was the installments of previous credit p...
# 217  What was the prescribed installment amount of ...
# 218  What the client actually paid on previous cred...
#
#                                    Special
# 211                                 hashed
# ...

# %% [markdown]
# ### HomeCredit_columns_description.csv
#
# This file contains descriptions for the columns in the various data files.

# %% [markdown]
# <img src="home_credit.png">
